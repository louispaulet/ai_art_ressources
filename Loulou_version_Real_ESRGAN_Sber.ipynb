# %% [markdown]
# # Installation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install git+https://github.com/sberbank-ai/Real-ESRGAN.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/sberbank-ai/Real-ESRGAN.git
#   Cloning https://github.com/sberbank-ai/Real-ESRGAN.git to /tmp/pip-req-build-dhhtf9c2
#   Running command git clone -q https://github.com/sberbank-ai/Real-ESRGAN.git /tmp/pip-req-build-dhhtf9c2
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from RealESRGAN==1.0) (1.21.6)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (from RealESRGAN==1.0) (4.6.0.66)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from RealESRGAN==1.0) (7.1.2)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from RealESRGAN==1.0) (1.12.1+cu113)
# Requirement already satisfied: torchvision>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from RealESRGAN==1.0) (0.13.1+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from RealESRGAN==1.0) (4.64.1)
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.10.0-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 2.1 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.7->RealESRGAN==1.0) (4.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.8.0->RealESRGAN==1.0) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->RealESRGAN==1.0) (4.12.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->RealESRGAN==1.0) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->RealESRGAN==1.0) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->RealESRGAN==1.0) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub->RealESRGAN==1.0) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub->RealESRGAN==1.0) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.8.0->RealESRGAN==1.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.8.0->RealESRGAN==1.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.8.0->RealESRGAN==1.0) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.8.0->RealESRGAN==1.0) (3.0.4)
# Building wheels for collected packages: RealESRGAN
#   Building wheel for RealESRGAN (setup.py) ... done
#   Created wheel for RealESRGAN: filename=RealESRGAN-1.0-py3-none-any.whl size=9135 sha256=71d9475d9be9b8d309fa1b52b472fd0e53c1273a078e9b3518ef201dd994d505
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w8wnvmqt/wheels/70/03/3f/182d6997f8fb3be93d5a86397612242994e94c63c8e31fe5b5
# Successfully built RealESRGAN
# Installing collected packages: huggingface-hub, RealESRGAN
# Successfully installed RealESRGAN-1.0 huggingface-hub-0.10.0

# %% [markdown]
# # Upscale images

# %%
#@title Create model
from RealESRGAN import RealESRGAN
from PIL import Image
import numpy as np
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('device:', device)

model_scale = "2" #@param ["2", "4", "8"] {allow-input: false}

model = RealESRGAN(device, scale=int(model_scale))
model.load_weights(f'weights/RealESRGAN_x{model_scale}.pth')
# Out:
# device: cuda
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/file_download.py:591: FutureWarning: `cached_download` is the legacy way to download files from the HF hub, please consider upgrading to `hf_hub_download`
#   FutureWarning,
# Downloading:   0%|          | 0.00/67.1M [00:00<?, ?B/s]
# Weights downloaded to: weights/RealESRGAN_x2.pth

# %% [markdown]
# ## OPTION: move files and fix filenames

# %%
# !cp -r /content/drive/MyDrive/AI/IMG2IMG_stable_diffusion/output/*.png /content/drive/MyDrive/AI/realesrgan_upscaling/input/

# %%
# %cd /content/drive/MyDrive/AI/realesrgan_upscaling/input/
# Out:
# /content/drive/MyDrive/AI/realesrgan_upscaling/input

# %%
# %%sh
# for file in *-*.png
#  do
#    newName="${file#*-}"
#    mv -- "${file}" "${newName}"
#  done

# %% [markdown]
# ## upscale

# %%
from glob import glob
input_path = "/content/drive/MyDrive/AI/realesrgan_upscaling/input"
filename_list = sorted(glob(input_path+"/*", recursive = True))

# %%
#@title Upload and upscale images or .tar archives
import os
from google.colab import files
import shutil
from io import BytesIO
import io
import tarfile

upload_folder = 'inputs'
result_folder = 'results'

os.makedirs(upload_folder, exist_ok=True)
os.makedirs(result_folder, exist_ok=True)

IMAGE_FORMATS = ('.png', '.jpg', '.jpeg', '.tiff', '.bmp', '.gif')

def image_to_tar_format(img, image_name):
    buff = BytesIO()
    if '.png' in image_name.lower():
        img = img.convert('RGBA')
        img.save(buff, format='PNG')
    else:
        img.save(buff, format='JPEG')
    buff.seek(0)
    fp = io.BufferedReader(buff)
    img_tar_info = tarfile.TarInfo(name=image_name)
    img_tar_info.size = len(buff.getvalue())
    return img_tar_info, fp

def process_tar(path_to_tar):
    processing_tar = tarfile.open(path_to_tar, mode='r')
    result_tar_path = os.path.join('results/', os.path.basename(path_to_tar))
    save_tar = tarfile.open(result_tar_path, 'w')

    for c, member in enumerate(processing_tar):
        print(f'{c}, processing {member.name}')

        if not member.name.endswith(IMAGE_FORMATS):
            continue

        try:
            img_bytes = BytesIO(processing_tar.extractfile(member.name).read())
            img_lr = Image.open(img_bytes, mode='r').convert('RGB')
        except Exception as err:
            print(f'Unable to open file {member.name}, skipping')
            continue

        img_sr = model.predict(np.array(img_lr))
        # adding to save_tar
        img_tar_info, fp = image_to_tar_format(img_sr, member.name)
        save_tar.addfile(img_tar_info, fp)

    processing_tar.close()
    save_tar.close()    
    print(f'Finished! Archive saved to {result_tar_path}')

def process_input(filename):
    if tarfile.is_tarfile(filename):
        process_tar(filename)
    else:
        result_image_path = os.path.join('results/', os.path.basename(filename))
        image = Image.open(filename).convert('RGB')
        sr_image = model.predict(np.array(image))
        sr_image.save(result_image_path)
        print(f'Finished! Image saved to {result_image_path}')

# upload files
# uploaded = files.upload()
for filename in filename_list:
    print('Processing:', filename)
    process_input(filename)

# # upload files
# uploaded = files.upload()
# for filename in uploaded.keys():
#     print('Processing:', filename)
#     process_input(filename)
# Out:
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0001image.png
# Finished! Image saved to results/img0001image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0002image.png
# Finished! Image saved to results/img0002image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0003image.png
# Finished! Image saved to results/img0003image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0004image.png
# Finished! Image saved to results/img0004image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0005image.png
# Finished! Image saved to results/img0005image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0006image.png
# Finished! Image saved to results/img0006image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0007image.png
# Finished! Image saved to results/img0007image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0008image.png
# Finished! Image saved to results/img0008image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0009image.png
# Finished! Image saved to results/img0009image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0010image.png
# Finished! Image saved to results/img0010image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0011image.png
# Finished! Image saved to results/img0011image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0012image.png
# Finished! Image saved to results/img0012image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0013image.png
# Finished! Image saved to results/img0013image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0014image.png
# Finished! Image saved to results/img0014image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0015image.png
# Finished! Image saved to results/img0015image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0016image.png
# Finished! Image saved to results/img0016image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0017image.png
# Finished! Image saved to results/img0017image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0018image.png
# Finished! Image saved to results/img0018image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0019image.png
# Finished! Image saved to results/img0019image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0020image.png
# Finished! Image saved to results/img0020image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0021image.png
# Finished! Image saved to results/img0021image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0022image.png
# Finished! Image saved to results/img0022image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0023image.png
# Finished! Image saved to results/img0023image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0024image.png
# Finished! Image saved to results/img0024image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0025image.png
# Finished! Image saved to results/img0025image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0026image.png
# Finished! Image saved to results/img0026image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0027image.png
# Finished! Image saved to results/img0027image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0028image.png
# Finished! Image saved to results/img0028image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0029image.png
# Finished! Image saved to results/img0029image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0030image.png
# Finished! Image saved to results/img0030image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0031image.png
# Finished! Image saved to results/img0031image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0032image.png
# Finished! Image saved to results/img0032image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0033image.png
# Finished! Image saved to results/img0033image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0034image.png
# Finished! Image saved to results/img0034image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0035image.png
# Finished! Image saved to results/img0035image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0036image.png
# Finished! Image saved to results/img0036image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0037image.png
# Finished! Image saved to results/img0037image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0038image.png
# Finished! Image saved to results/img0038image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0039image.png
# Finished! Image saved to results/img0039image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0040image.png
# Finished! Image saved to results/img0040image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0041image.png
# Finished! Image saved to results/img0041image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0042image.png
# Finished! Image saved to results/img0042image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0043image.png
# Finished! Image saved to results/img0043image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0044image.png
# Finished! Image saved to results/img0044image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0045image.png
# Finished! Image saved to results/img0045image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0046image.png
# Finished! Image saved to results/img0046image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0047image.png
# Finished! Image saved to results/img0047image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0048image.png
# Finished! Image saved to results/img0048image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0049image.png
# Finished! Image saved to results/img0049image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0050image.png
# Finished! Image saved to results/img0050image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0051image.png
# Finished! Image saved to results/img0051image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0052image.png
# Finished! Image saved to results/img0052image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0053image.png
# Finished! Image saved to results/img0053image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0054image.png
# Finished! Image saved to results/img0054image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0055image.png
# Finished! Image saved to results/img0055image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0056image.png
# Finished! Image saved to results/img0056image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0057image.png
# Finished! Image saved to results/img0057image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0058image.png
# Finished! Image saved to results/img0058image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0059image.png
# Finished! Image saved to results/img0059image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0060image.png
# Finished! Image saved to results/img0060image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0061image.png
# Finished! Image saved to results/img0061image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0062image.png
# Finished! Image saved to results/img0062image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0063image.png
# Finished! Image saved to results/img0063image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0064image.png
# Finished! Image saved to results/img0064image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0065image.png
# Finished! Image saved to results/img0065image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0066image.png
# Finished! Image saved to results/img0066image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0067image.png
# Finished! Image saved to results/img0067image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0068image.png
# Finished! Image saved to results/img0068image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0069image.png
# Finished! Image saved to results/img0069image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0070image.png
# Finished! Image saved to results/img0070image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0071image.png
# Finished! Image saved to results/img0071image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0072image.png
# Finished! Image saved to results/img0072image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0073image.png
# Finished! Image saved to results/img0073image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0074image.png
# Finished! Image saved to results/img0074image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0075image.png
# Finished! Image saved to results/img0075image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0076image.png
# Finished! Image saved to results/img0076image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0077image.png
# Finished! Image saved to results/img0077image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0078image.png
# Finished! Image saved to results/img0078image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0079image.png
# Finished! Image saved to results/img0079image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0080image.png
# Finished! Image saved to results/img0080image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0081image.png
# Finished! Image saved to results/img0081image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0082image.png
# Finished! Image saved to results/img0082image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0083image.png
# Finished! Image saved to results/img0083image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0084image.png
# Finished! Image saved to results/img0084image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0085image.png
# Finished! Image saved to results/img0085image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0086image.png
# Finished! Image saved to results/img0086image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0087image.png
# Finished! Image saved to results/img0087image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0088image.png
# Finished! Image saved to results/img0088image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0089image.png
# Finished! Image saved to results/img0089image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0090image.png
# Finished! Image saved to results/img0090image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0091image.png
# Finished! Image saved to results/img0091image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0092image.png
# Finished! Image saved to results/img0092image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0093image.png
# Finished! Image saved to results/img0093image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0094image.png
# Finished! Image saved to results/img0094image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0095image.png
# Finished! Image saved to results/img0095image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0096image.png
# Finished! Image saved to results/img0096image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0097image.png
# Finished! Image saved to results/img0097image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0098image.png
# Finished! Image saved to results/img0098image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0099image.png
# Finished! Image saved to results/img0099image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0100image.png
# Finished! Image saved to results/img0100image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0101image.png
# Finished! Image saved to results/img0101image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0102image.png
# Finished! Image saved to results/img0102image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0103image.png
# Finished! Image saved to results/img0103image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0104image.png
# Finished! Image saved to results/img0104image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0105image.png
# Finished! Image saved to results/img0105image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0106image.png
# Finished! Image saved to results/img0106image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0107image.png
# Finished! Image saved to results/img0107image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0108image.png
# Finished! Image saved to results/img0108image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0109image.png
# Finished! Image saved to results/img0109image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0110image.png
# Finished! Image saved to results/img0110image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0111image.png
# Finished! Image saved to results/img0111image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0112image.png
# Finished! Image saved to results/img0112image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0113image.png
# Finished! Image saved to results/img0113image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0114image.png
# Finished! Image saved to results/img0114image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0115image.png
# Finished! Image saved to results/img0115image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0116image.png
# Finished! Image saved to results/img0116image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0117image.png
# Finished! Image saved to results/img0117image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0118image.png
# Finished! Image saved to results/img0118image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0119image.png
# Finished! Image saved to results/img0119image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0120image.png
# Finished! Image saved to results/img0120image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0121image.png
# Finished! Image saved to results/img0121image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0122image.png
# Finished! Image saved to results/img0122image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0123image.png
# Finished! Image saved to results/img0123image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0124image.png
# Finished! Image saved to results/img0124image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0125image.png
# Finished! Image saved to results/img0125image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0126image.png
# Finished! Image saved to results/img0126image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0127image.png
# Finished! Image saved to results/img0127image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0128image.png
# Finished! Image saved to results/img0128image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0129image.png
# Finished! Image saved to results/img0129image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0130image.png
# Finished! Image saved to results/img0130image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0131image.png
# Finished! Image saved to results/img0131image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0132image.png
# Finished! Image saved to results/img0132image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0133image.png
# Finished! Image saved to results/img0133image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0134image.png
# Finished! Image saved to results/img0134image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0135image.png
# Finished! Image saved to results/img0135image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0136image.png
# Finished! Image saved to results/img0136image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0137image.png
# Finished! Image saved to results/img0137image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0138image.png
# Finished! Image saved to results/img0138image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0139image.png
# Finished! Image saved to results/img0139image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0140image.png
# Finished! Image saved to results/img0140image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0141image.png
# Finished! Image saved to results/img0141image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0142image.png
# Finished! Image saved to results/img0142image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0143image.png
# Finished! Image saved to results/img0143image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0144image.png
# Finished! Image saved to results/img0144image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0145image.png
# Finished! Image saved to results/img0145image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0146image.png
# Finished! Image saved to results/img0146image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0147image.png
# Finished! Image saved to results/img0147image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0148image.png
# Finished! Image saved to results/img0148image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0149image.png
# Finished! Image saved to results/img0149image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0150image.png
# Finished! Image saved to results/img0150image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0151image.png
# Finished! Image saved to results/img0151image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0152image.png
# Finished! Image saved to results/img0152image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0153image.png
# Finished! Image saved to results/img0153image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0154image.png
# Finished! Image saved to results/img0154image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0155image.png
# Finished! Image saved to results/img0155image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0156image.png
# Finished! Image saved to results/img0156image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0157image.png
# Finished! Image saved to results/img0157image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0158image.png
# Finished! Image saved to results/img0158image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0159image.png
# Finished! Image saved to results/img0159image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0160image.png
# Finished! Image saved to results/img0160image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0161image.png
# Finished! Image saved to results/img0161image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0162image.png
# Finished! Image saved to results/img0162image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0163image.png
# Finished! Image saved to results/img0163image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0164image.png
# Finished! Image saved to results/img0164image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0165image.png
# Finished! Image saved to results/img0165image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0166image.png
# Finished! Image saved to results/img0166image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0167image.png
# Finished! Image saved to results/img0167image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0168image.png
# Finished! Image saved to results/img0168image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0169image.png
# Finished! Image saved to results/img0169image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0170image.png
# Finished! Image saved to results/img0170image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0171image.png
# Finished! Image saved to results/img0171image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0172image.png
# Finished! Image saved to results/img0172image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0173image.png
# Finished! Image saved to results/img0173image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0174image.png
# Finished! Image saved to results/img0174image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0175image.png
# Finished! Image saved to results/img0175image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0176image.png
# Finished! Image saved to results/img0176image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0177image.png
# Finished! Image saved to results/img0177image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0178image.png
# Finished! Image saved to results/img0178image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0179image.png
# Finished! Image saved to results/img0179image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0180image.png
# Finished! Image saved to results/img0180image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0181image.png
# Finished! Image saved to results/img0181image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0182image.png
# Finished! Image saved to results/img0182image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0183image.png
# Finished! Image saved to results/img0183image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0184image.png
# Finished! Image saved to results/img0184image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0185image.png
# Finished! Image saved to results/img0185image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0186image.png
# Finished! Image saved to results/img0186image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0187image.png
# Finished! Image saved to results/img0187image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0188image.png
# Finished! Image saved to results/img0188image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0189image.png
# Finished! Image saved to results/img0189image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0190image.png
# Finished! Image saved to results/img0190image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0191image.png
# Finished! Image saved to results/img0191image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0192image.png
# Finished! Image saved to results/img0192image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0193image.png
# Finished! Image saved to results/img0193image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0194image.png
# Finished! Image saved to results/img0194image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0195image.png
# Finished! Image saved to results/img0195image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0196image.png
# Finished! Image saved to results/img0196image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0197image.png
# Finished! Image saved to results/img0197image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0198image.png
# Finished! Image saved to results/img0198image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0199image.png
# Finished! Image saved to results/img0199image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0200image.png
# Finished! Image saved to results/img0200image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0201image.png
# Finished! Image saved to results/img0201image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0202image.png
# Finished! Image saved to results/img0202image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0203image.png
# Finished! Image saved to results/img0203image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0204image.png
# Finished! Image saved to results/img0204image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0205image.png
# Finished! Image saved to results/img0205image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0206image.png
# Finished! Image saved to results/img0206image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0207image.png
# Finished! Image saved to results/img0207image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0208image.png
# Finished! Image saved to results/img0208image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0209image.png
# Finished! Image saved to results/img0209image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0210image.png
# Finished! Image saved to results/img0210image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0211image.png
# Finished! Image saved to results/img0211image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0212image.png
# Finished! Image saved to results/img0212image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0213image.png
# Finished! Image saved to results/img0213image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0214image.png
# Finished! Image saved to results/img0214image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0215image.png
# Finished! Image saved to results/img0215image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0216image.png
# Finished! Image saved to results/img0216image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0217image.png
# Finished! Image saved to results/img0217image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0218image.png
# Finished! Image saved to results/img0218image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0219image.png
# Finished! Image saved to results/img0219image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0220image.png
# Finished! Image saved to results/img0220image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0221image.png
# Finished! Image saved to results/img0221image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0222image.png
# Finished! Image saved to results/img0222image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0223image.png
# Finished! Image saved to results/img0223image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0224image.png
# Finished! Image saved to results/img0224image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0225image.png
# Finished! Image saved to results/img0225image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0226image.png
# Finished! Image saved to results/img0226image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0227image.png
# Finished! Image saved to results/img0227image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0228image.png
# Finished! Image saved to results/img0228image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0229image.png
# Finished! Image saved to results/img0229image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0230image.png
# Finished! Image saved to results/img0230image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0231image.png
# Finished! Image saved to results/img0231image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0232image.png
# Finished! Image saved to results/img0232image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0233image.png
# Finished! Image saved to results/img0233image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0234image.png
# Finished! Image saved to results/img0234image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0235image.png
# Finished! Image saved to results/img0235image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0236image.png
# Finished! Image saved to results/img0236image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0237image.png
# Finished! Image saved to results/img0237image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0238image.png
# Finished! Image saved to results/img0238image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0239image.png
# Finished! Image saved to results/img0239image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0240image.png
# Finished! Image saved to results/img0240image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0241image.png
# Finished! Image saved to results/img0241image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0242image.png
# Finished! Image saved to results/img0242image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0243image.png
# Finished! Image saved to results/img0243image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0244image.png
# Finished! Image saved to results/img0244image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0245image.png
# Finished! Image saved to results/img0245image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0246image.png
# Finished! Image saved to results/img0246image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0247image.png
# Finished! Image saved to results/img0247image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0248image.png
# Finished! Image saved to results/img0248image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0249image.png
# Finished! Image saved to results/img0249image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0250image.png
# Finished! Image saved to results/img0250image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0251image.png
# Finished! Image saved to results/img0251image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0252image.png
# Finished! Image saved to results/img0252image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0253image.png
# Finished! Image saved to results/img0253image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0254image.png
# Finished! Image saved to results/img0254image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0255image.png
# Finished! Image saved to results/img0255image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0256image.png
# Finished! Image saved to results/img0256image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0257image.png
# Finished! Image saved to results/img0257image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0258image.png
# Finished! Image saved to results/img0258image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0259image.png
# Finished! Image saved to results/img0259image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0260image.png
# Finished! Image saved to results/img0260image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0261image.png
# Finished! Image saved to results/img0261image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0262image.png
# Finished! Image saved to results/img0262image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0263image.png
# Finished! Image saved to results/img0263image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0264image.png
# Finished! Image saved to results/img0264image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0265image.png
# Finished! Image saved to results/img0265image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0266image.png
# Finished! Image saved to results/img0266image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0267image.png
# Finished! Image saved to results/img0267image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0268image.png
# Finished! Image saved to results/img0268image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0269image.png
# Finished! Image saved to results/img0269image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0270image.png
# Finished! Image saved to results/img0270image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0271image.png
# Finished! Image saved to results/img0271image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0272image.png
# Finished! Image saved to results/img0272image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0273image.png
# Finished! Image saved to results/img0273image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0274image.png
# Finished! Image saved to results/img0274image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0275image.png
# Finished! Image saved to results/img0275image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0276image.png
# Finished! Image saved to results/img0276image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0277image.png
# Finished! Image saved to results/img0277image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0278image.png
# Finished! Image saved to results/img0278image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0279image.png
# Finished! Image saved to results/img0279image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0280image.png
# Finished! Image saved to results/img0280image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0281image.png
# Finished! Image saved to results/img0281image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0282image.png
# Finished! Image saved to results/img0282image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0283image.png
# Finished! Image saved to results/img0283image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0284image.png
# Finished! Image saved to results/img0284image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0285image.png
# Finished! Image saved to results/img0285image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0286image.png
# Finished! Image saved to results/img0286image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0287image.png
# Finished! Image saved to results/img0287image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0288image.png
# Finished! Image saved to results/img0288image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0289image.png
# Finished! Image saved to results/img0289image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0290image.png
# Finished! Image saved to results/img0290image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0291image.png
# Finished! Image saved to results/img0291image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0292image.png
# Finished! Image saved to results/img0292image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0293image.png
# Finished! Image saved to results/img0293image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0294image.png
# Finished! Image saved to results/img0294image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0295image.png
# Finished! Image saved to results/img0295image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0296image.png
# Finished! Image saved to results/img0296image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0297image.png
# Finished! Image saved to results/img0297image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0298image.png
# Finished! Image saved to results/img0298image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0299image.png
# Finished! Image saved to results/img0299image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0300image.png
# Finished! Image saved to results/img0300image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0301image.png
# Finished! Image saved to results/img0301image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0302image.png
# Finished! Image saved to results/img0302image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0303image.png
# Finished! Image saved to results/img0303image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0304image.png
# Finished! Image saved to results/img0304image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0305image.png
# Finished! Image saved to results/img0305image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0306image.png
# Finished! Image saved to results/img0306image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0307image.png
# Finished! Image saved to results/img0307image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0308image.png
# Finished! Image saved to results/img0308image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0309image.png
# Finished! Image saved to results/img0309image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0310image.png
# Finished! Image saved to results/img0310image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0311image.png
# Finished! Image saved to results/img0311image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0312image.png
# Finished! Image saved to results/img0312image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0313image.png
# Finished! Image saved to results/img0313image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0314image.png
# Finished! Image saved to results/img0314image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0315image.png
# Finished! Image saved to results/img0315image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0316image.png
# Finished! Image saved to results/img0316image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0317image.png
# Finished! Image saved to results/img0317image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0318image.png
# Finished! Image saved to results/img0318image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0319image.png
# Finished! Image saved to results/img0319image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0320image.png
# Finished! Image saved to results/img0320image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0321image.png
# Finished! Image saved to results/img0321image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0322image.png
# Finished! Image saved to results/img0322image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0323image.png
# Finished! Image saved to results/img0323image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0324image.png
# Finished! Image saved to results/img0324image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0325image.png
# Finished! Image saved to results/img0325image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0326image.png
# Finished! Image saved to results/img0326image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0327image.png
# Finished! Image saved to results/img0327image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0328image.png
# Finished! Image saved to results/img0328image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0329image.png
# Finished! Image saved to results/img0329image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0330image.png
# Finished! Image saved to results/img0330image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0331image.png
# Finished! Image saved to results/img0331image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0332image.png
# Finished! Image saved to results/img0332image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0333image.png
# Finished! Image saved to results/img0333image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0334image.png
# Finished! Image saved to results/img0334image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0335image.png
# Finished! Image saved to results/img0335image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0336image.png
# Finished! Image saved to results/img0336image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0337image.png
# Finished! Image saved to results/img0337image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0338image.png
# Finished! Image saved to results/img0338image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0339image.png
# Finished! Image saved to results/img0339image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0340image.png
# Finished! Image saved to results/img0340image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0341image.png
# Finished! Image saved to results/img0341image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0342image.png
# Finished! Image saved to results/img0342image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0343image.png
# Finished! Image saved to results/img0343image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0344image.png
# Finished! Image saved to results/img0344image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0345image.png
# Finished! Image saved to results/img0345image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0346image.png
# Finished! Image saved to results/img0346image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0347image.png
# Finished! Image saved to results/img0347image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0348image.png
# Finished! Image saved to results/img0348image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0349image.png
# Finished! Image saved to results/img0349image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0350image.png
# Finished! Image saved to results/img0350image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0351image.png
# Finished! Image saved to results/img0351image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0352image.png
# Finished! Image saved to results/img0352image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0353image.png
# Finished! Image saved to results/img0353image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0354image.png
# Finished! Image saved to results/img0354image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0355image.png
# Finished! Image saved to results/img0355image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0356image.png
# Finished! Image saved to results/img0356image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0357image.png
# Finished! Image saved to results/img0357image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0358image.png
# Finished! Image saved to results/img0358image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0359image.png
# Finished! Image saved to results/img0359image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0360image.png
# Finished! Image saved to results/img0360image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0361image.png
# Finished! Image saved to results/img0361image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0362image.png
# Finished! Image saved to results/img0362image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0363image.png
# Finished! Image saved to results/img0363image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img0364image.png
# ...
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1759image.png
# Finished! Image saved to results/img1759image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1760image.png
# Finished! Image saved to results/img1760image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1761image.png
# Finished! Image saved to results/img1761image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1762image.png
# Finished! Image saved to results/img1762image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1763image.png
# Finished! Image saved to results/img1763image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1764image.png
# Finished! Image saved to results/img1764image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1765image.png
# Finished! Image saved to results/img1765image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1766image.png
# Finished! Image saved to results/img1766image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1767image.png
# Finished! Image saved to results/img1767image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1768image.png
# Finished! Image saved to results/img1768image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1769image.png
# Finished! Image saved to results/img1769image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1770image.png
# Finished! Image saved to results/img1770image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1771image.png
# Finished! Image saved to results/img1771image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1772image.png
# Finished! Image saved to results/img1772image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1773image.png
# Finished! Image saved to results/img1773image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1774image.png
# Finished! Image saved to results/img1774image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1775image.png
# Finished! Image saved to results/img1775image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1776image.png
# Finished! Image saved to results/img1776image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1777image.png
# Finished! Image saved to results/img1777image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1778image.png
# Finished! Image saved to results/img1778image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1779image.png
# Finished! Image saved to results/img1779image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1780image.png
# Finished! Image saved to results/img1780image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1781image.png
# Finished! Image saved to results/img1781image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1782image.png
# Finished! Image saved to results/img1782image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1783image.png
# Finished! Image saved to results/img1783image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1784image.png
# Finished! Image saved to results/img1784image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1785image.png
# Finished! Image saved to results/img1785image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1786image.png
# Finished! Image saved to results/img1786image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1787image.png
# Finished! Image saved to results/img1787image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1788image.png
# Finished! Image saved to results/img1788image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1789image.png
# Finished! Image saved to results/img1789image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1790image.png
# Finished! Image saved to results/img1790image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1791image.png
# Finished! Image saved to results/img1791image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1792image.png
# Finished! Image saved to results/img1792image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1793image.png
# Finished! Image saved to results/img1793image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1794image.png
# Finished! Image saved to results/img1794image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1795image.png
# Finished! Image saved to results/img1795image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1796image.png
# Finished! Image saved to results/img1796image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1797image.png
# Finished! Image saved to results/img1797image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1798image.png
# Finished! Image saved to results/img1798image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1799image.png
# Finished! Image saved to results/img1799image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1800image.png
# Finished! Image saved to results/img1800image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1801image.png
# Finished! Image saved to results/img1801image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1802image.png
# Finished! Image saved to results/img1802image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1803image.png
# Finished! Image saved to results/img1803image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1804image.png
# Finished! Image saved to results/img1804image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1805image.png
# Finished! Image saved to results/img1805image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1806image.png
# Finished! Image saved to results/img1806image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1807image.png
# Finished! Image saved to results/img1807image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1808image.png
# Finished! Image saved to results/img1808image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1809image.png
# Finished! Image saved to results/img1809image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1810image.png
# Finished! Image saved to results/img1810image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1811image.png
# Finished! Image saved to results/img1811image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1812image.png
# Finished! Image saved to results/img1812image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1813image.png
# Finished! Image saved to results/img1813image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1814image.png
# Finished! Image saved to results/img1814image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1815image.png
# Finished! Image saved to results/img1815image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1816image.png
# Finished! Image saved to results/img1816image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1817image.png
# Finished! Image saved to results/img1817image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1818image.png
# Finished! Image saved to results/img1818image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1819image.png
# Finished! Image saved to results/img1819image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1820image.png
# Finished! Image saved to results/img1820image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1821image.png
# Finished! Image saved to results/img1821image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1822image.png
# Finished! Image saved to results/img1822image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1823image.png
# Finished! Image saved to results/img1823image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1824image.png
# Finished! Image saved to results/img1824image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1825image.png
# Finished! Image saved to results/img1825image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1826image.png
# Finished! Image saved to results/img1826image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1827image.png
# Finished! Image saved to results/img1827image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1828image.png
# Finished! Image saved to results/img1828image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1829image.png
# Finished! Image saved to results/img1829image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1830image.png
# Finished! Image saved to results/img1830image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1831image.png
# Finished! Image saved to results/img1831image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1832image.png
# Finished! Image saved to results/img1832image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1833image.png
# Finished! Image saved to results/img1833image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1834image.png
# Finished! Image saved to results/img1834image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1835image.png
# Finished! Image saved to results/img1835image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1836image.png
# Finished! Image saved to results/img1836image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1837image.png
# Finished! Image saved to results/img1837image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1838image.png
# Finished! Image saved to results/img1838image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1839image.png
# Finished! Image saved to results/img1839image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1840image.png
# Finished! Image saved to results/img1840image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1841image.png
# Finished! Image saved to results/img1841image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1842image.png
# Finished! Image saved to results/img1842image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1843image.png
# Finished! Image saved to results/img1843image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1844image.png
# Finished! Image saved to results/img1844image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1845image.png
# Finished! Image saved to results/img1845image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1846image.png
# Finished! Image saved to results/img1846image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1847image.png
# Finished! Image saved to results/img1847image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1848image.png
# Finished! Image saved to results/img1848image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1849image.png
# Finished! Image saved to results/img1849image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1850image.png
# Finished! Image saved to results/img1850image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1851image.png
# Finished! Image saved to results/img1851image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1852image.png
# Finished! Image saved to results/img1852image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1853image.png
# Finished! Image saved to results/img1853image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1854image.png
# Finished! Image saved to results/img1854image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1855image.png
# Finished! Image saved to results/img1855image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1856image.png
# Finished! Image saved to results/img1856image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1857image.png
# Finished! Image saved to results/img1857image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1858image.png
# Finished! Image saved to results/img1858image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1859image.png
# Finished! Image saved to results/img1859image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1860image.png
# Finished! Image saved to results/img1860image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1861image.png
# Finished! Image saved to results/img1861image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1862image.png
# Finished! Image saved to results/img1862image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1863image.png
# Finished! Image saved to results/img1863image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1864image.png
# Finished! Image saved to results/img1864image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1865image.png
# Finished! Image saved to results/img1865image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1866image.png
# Finished! Image saved to results/img1866image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1867image.png
# Finished! Image saved to results/img1867image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1868image.png
# Finished! Image saved to results/img1868image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1869image.png
# Finished! Image saved to results/img1869image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1870image.png
# Finished! Image saved to results/img1870image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1871image.png
# Finished! Image saved to results/img1871image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1872image.png
# Finished! Image saved to results/img1872image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1873image.png
# Finished! Image saved to results/img1873image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1874image.png
# Finished! Image saved to results/img1874image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1875image.png
# Finished! Image saved to results/img1875image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1876image.png
# Finished! Image saved to results/img1876image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1877image.png
# Finished! Image saved to results/img1877image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1878image.png
# Finished! Image saved to results/img1878image.png
# Processing: /content/drive/MyDrive/AI/realesrgan_upscaling/input/img1879image.png
# Finished! Image saved to results/img1879image.png
