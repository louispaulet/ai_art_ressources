# %% [markdown]
# # Following install guide from here: https://github.com/jquesnelle/txt2imghd
#
# ## Conclusion Here!
#
# 1- Couldn't get the model.ckpt due to size limits in the instance => make drive bigger next time
# 2- SUDO commands are not availiable, it is impossible to apt update or upgrade or install => everything should be inside of a conda env
# 3- GIT LFS will ask too many credentials, maybe a CLI login or something

# %% [markdown]
# # Clone repos

# %%
# !git clone https://github.com/CompVis/stable-diffusion.git
# Out:
# Cloning into 'stable-diffusion'...
# remote: Enumerating objects: 313, done.
# remote: Total 313 (delta 0), reused 0 (delta 0), pack-reused 313
# Receiving objects: 100% (313/313), 42.63 MiB | 60.22 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
# !git clone https://github.com/jquesnelle/txt2imghd.git
# Out:
# Cloning into 'txt2imghd'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 59 (delta 19), reused 16 (delta 9), pack-reused 24
# Unpacking objects: 100% (59/59), 18.49 MiB | 19.72 MiB/s, done.

# %%
# !cp txt2imghd/txt2imghd.py stable-diffusion/scripts/txt2imghd.py

# %% [markdown]
# # Check GPU

# %%
# !nvidia-smi
# Out:
# Sat Oct 29 01:11:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:1E.0 Off |                    0 |
# | N/A   40C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# # Move files & download+extract Real-ESRGAN

# %%
# the link comes from here: https://github.com/xinntao/Real-ESRGAN/releases
# !cd stable-diffusion/ && wget https://github.com/xinntao/Real-ESRGAN/archive/refs/tags/v0.3.0.zip
# Out:
# --2022-10-29 01:14:50--  https://github.com/xinntao/Real-ESRGAN/archive/refs/tags/v0.3.0.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/xinntao/Real-ESRGAN/zip/refs/tags/v0.3.0 [following]
# --2022-10-29 01:14:50--  https://codeload.github.com/xinntao/Real-ESRGAN/zip/refs/tags/v0.3.0
# Resolving codeload.github.com (codeload.github.com)... 140.82.113.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.113.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: 'v0.3.0.zip'
#
# v0.3.0.zip              [  <=>               ]   4.86M  20.1MB/s    in 0.2s
#
# 2022-10-29 01:14:51 (20.1 MB/s) - 'v0.3.0.zip' saved [5098516]

# %%
# unzip the file inside stable-diffusion
# !cd stable-diffusion/ && unzip "v0.3.0.zip"
# Out:
# Archive:  v0.3.0.zip
# fa4c8a03ae3dbc9ea6ed471a6ab5da94ac15c2ea
#    creating: Real-ESRGAN-0.3.0/
#    creating: Real-ESRGAN-0.3.0/.github/
#    creating: Real-ESRGAN-0.3.0/.github/workflows/
#   inflating: Real-ESRGAN-0.3.0/.github/workflows/no-response.yml
#   inflating: Real-ESRGAN-0.3.0/.github/workflows/publish-pip.yml
#   inflating: Real-ESRGAN-0.3.0/.github/workflows/pylint.yml
#   inflating: Real-ESRGAN-0.3.0/.github/workflows/release.yml
#   inflating: Real-ESRGAN-0.3.0/.gitignore
#   inflating: Real-ESRGAN-0.3.0/.pre-commit-config.yaml
#    creating: Real-ESRGAN-0.3.0/.vscode/
#   inflating: Real-ESRGAN-0.3.0/.vscode/settings.json
#   inflating: Real-ESRGAN-0.3.0/CODE_OF_CONDUCT.md
#   inflating: Real-ESRGAN-0.3.0/LICENSE
#   inflating: Real-ESRGAN-0.3.0/MANIFEST.in
#   inflating: Real-ESRGAN-0.3.0/README.md
#   inflating: Real-ESRGAN-0.3.0/README_CN.md
#  extracting: Real-ESRGAN-0.3.0/VERSION
#    creating: Real-ESRGAN-0.3.0/assets/
# ...

# %% [markdown]
# # Install libs

# %%
conda init bash
# Out:
# no change     /opt/conda/condabin/conda
# no change     /opt/conda/bin/conda
# no change     /opt/conda/bin/conda-env
# no change     /opt/conda/bin/activate
# no change     /opt/conda/bin/deactivate
# no change     /opt/conda/etc/profile.d/conda.sh
# no change     /opt/conda/etc/fish/conf.d/conda.fish
# no change     /opt/conda/shell/condabin/Conda.psm1
# no change     /opt/conda/shell/condabin/conda-hook.ps1
# no change     /opt/conda/lib/python3.9/site-packages/xontrib/conda.xsh
# no change     /opt/conda/etc/profile.d/conda.csh
# no change     /home/studio-lab-user/.bashrc
# No action taken.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

os.chdir("stable-diffusion/")

# %%
# !conda update -y -n base conda
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     brotlipy-0.7.0             |py39hb9d737c_1005         342 KB  conda-forge
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     ca-certificates-2022.9.24  |       ha878542_0         150 KB  conda-forge
#     certifi-2022.9.24          |     pyhd8ed1ab_0         155 KB  conda-forge
#     cffi-1.15.1                |   py39he91dace_2         230 KB  conda-forge
#     charset-normalizer-2.1.1   |     pyhd8ed1ab_0          36 KB  conda-forge
#     colorama-0.4.6             |     pyhd8ed1ab_0          25 KB  conda-forge
# ...

# %%
# !conda update --all -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/studio-lab-user/.conda/envs/default
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asttokens-2.0.8            |     pyhd8ed1ab_0          24 KB  conda-forge
#     debugpy-1.6.3              |   py39h5a03fae_1         2.0 MB  conda-forge
#     executing-1.1.1            |     pyhd8ed1ab_0          23 KB  conda-forge
#     importlib-metadata-5.0.0   |     pyha770c72_1          23 KB  conda-forge
#     importlib_resources-5.10.0 |     pyhd8ed1ab_0          29 KB  conda-forge
#     ipykernel-6.16.2           |     pyh210e3f2_0         100 KB  conda-forge
# ...

# %%
# !conda env remove -n ldm
# Out:
# Remove all packages in environment /home/studio-lab-user/.conda/envs/ldm:

# %%
# !conda env create -f stable-diffusion/environment.yaml
# !conda activate ldm
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: | By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
# Installing pip dependencies: \ Ran pip subprocess with arguments:
# ['/home/studio-lab-user/.conda/envs/ldm/bin/python', '-m', 'pip', 'install', '-U', '-r', '/home/studio-lab-user/sagemaker-studiolab-notebooks/stable-diffusion/condaenv.zgmol7j9.requirements.txt']
# Pip subprocess output:
# ...

# %% [markdown]
# # Fix bug #1

# %%
# https://stackoverflow.com/questions/70553701/couldnt-import-cv2-in-sagemaker-studio-lab
# !pip uninstall opencv-python -y
# !pip install opencv-python-headless

# %% [markdown]
# # Download the weights

# %%
# script is looking for the model here: 'models/ldm/stable-diffusion-v1/model.ckpt'
# !mkdir stable-diffusion/models/ldm/stable-diffusion-v1

# %%
# !git lfs install

# authentication is handled in cli
# !git clone https://huggingface.co/CompVis/stable-diffusion-v-1-4-original
# Out:
# Error: Failed to call git rev-parse --git-dir: exit status 128
# Git LFS initialized.
# Cloning into 'stable-diffusion-v-1-4-original'...
# Username for 'https://huggingface.co': ^C

# %%
# git lfs pull --include sd-v1-4.ckpt

# %% [markdown]
# # RUN

# %%
# !python scripts/txt2imghd.py
# Out:
# python: can't open file '/home/studio-lab-user/sagemaker-studiolab-notebooks/scripts/txt2imghd.py': [Errno 2] No such file or directory

# %%
stable-diffusion/
